# %%
from ultralytics import YOLO

# Initialize the YOLOv8 model with pre-trained weights
model = YOLO("yolo11n.pt")

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ecQ4qPm4i9fsQ7OBeA3r")
project = rf.workspace("hku-uas-identify-shape-ziahx").project("hku-uas-identify-shape")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from ultralytics import YOLO

model = YOLO('yolo11n-seg.pt')   # seg model, not detect

results = model.train(
    data='dataset/data.yaml',
    epochs=50,
    imgsz=640,
    device='cuda',
    hsv_h=0.5,
    hsv_s=0.5,
    hsv_v=0.5,
    degrees=15.0,
    flipud=0.5,
    fliplr=0.5
)
# Out:
# Ultralytics 8.4.31  Python-3.11.15 torch-2.11.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...
